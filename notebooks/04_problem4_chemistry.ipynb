# %% [markdown]
# # 04 — Does This Player Fit? (Chemistry Classifier)
#
# **Problem:** Given a team's tactical DNA, does a player fit their system?
#
# **Approach:** Join players to their actual teams via `club_team_id`. Build a team profile vector from tactic columns. Train a Random Forest Classifier — positive label = player plays for this team, negative = player does not. Output is a fit probability score.

# %%
import pandas as pd
import numpy as np
from pipeline.export import load_processed_players, load_processed_teams

players = load_processed_players()
teams   = load_processed_teams()
print(players.shape, teams.shape)

# %% [markdown]
# ## 1. Build training pairs
#
# **Positive samples:** player X currently plays for team Y → label 1
# **Negative samples:** player X does NOT play for team Y → label 0 (sample randomly to balance)

# %%
# TODO:
# 1. Join players to teams on club_team_id == team_id (same fifa_version)
# 2. Each joined row is a positive sample
# 3. For negatives: for each player, randomly sample a team they DON'T play for
#    Match the number of negatives to positives (balanced classes)
# 4. Feature vector = player stat cols + team tactic vector cols (tv_*)
# 5. Label = 1 (plays for team) or 0 (does not)
pass

# %% [markdown]
# ## 2. Train Random Forest Classifier

# %%
# TODO:
# from sklearn.ensemble import RandomForestClassifier
# Split by player_id to avoid leakage
# rf = RandomForestClassifier(n_estimators=200, max_depth=12, random_state=42)
# rf.fit(X_train, y_train)

# %% [markdown]
# ## 3. Evaluate

# %%
# TODO — classification report, ROC-AUC, feature importance

# %% [markdown]
# ## 4. Save

# %%
import joblib
# joblib.dump(rf, '../models/saved/problem4_chemistry.joblib')
# joblib.dump(feature_cols, '../models/saved/problem4_features.joblib')
